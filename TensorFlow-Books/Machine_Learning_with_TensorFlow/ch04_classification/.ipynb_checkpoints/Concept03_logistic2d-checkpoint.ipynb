# %% [markdown]
# # Ch `04`: Concept `03`

# %% [markdown]
# ## Logistic regression in higher dimensions

# %% [markdown]
# Set up the imports and hyper-parameters

# %%
# %matplotlib inline
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

learning_rate = 0.1
training_epochs = 2000

# %% [markdown]
# Define positive and negative to classify 2D data points:

# %%
x1_label1 = np.random.normal(3, 1, 1000)
print x1_label1
x2_label1 = np.random.normal(2, 1, 1000)
x1_label2 = np.random.normal(7, 1, 1000)
x2_label2 = np.random.normal(6, 1, 1000)
x1s = np.append(x1_label1, x1_label2)
print x1s.shape()
x2s = np.append(x2_label1, x2_label2)
ys = np.asarray([0.] * len(x1_label1) + [1.] * len(x1_label2))
# Out:
# [ 4.21900006  2.94657505  2.28216589  2.32618124  3.05262692  1.6147981
#   0.73548712  1.78245436  3.72344918  1.57393824  2.99288444  4.24333609
#   0.94684202  2.46997444  3.80804635  2.91873875  5.04872779  2.44423193
#   3.37624646  4.27966913  3.58913268  2.36618006  3.8194909   5.06512215
#   4.12810861  2.93638732  3.58996615  1.60245399  4.00722921  3.57604439
#   1.3260042   1.39528996  2.69172181  3.50570631  3.79637802  3.42171902
#   3.67935617  2.81091678  1.83932984  1.90627228  2.23160453  4.22692314
#   3.56993764  1.22814075  3.50848821  2.57275547  2.23400985  4.37478014
#   1.21652104  0.73520816  2.67865459  2.06056319  3.40703957  2.06441135
#   3.62536415  4.06018262  1.79119282  2.44420929  2.57181761  2.7857173
#   3.25816838  2.77790499  2.05280188  1.4793223   2.35663399  3.88429207
#   2.92064451  3.90354436  4.89108307  4.62558381  4.10131555  1.83853132
#   3.17931885  3.28025091  3.89500619  2.23253286  5.28518068  3.09153971
#   2.49285531  3.45724363  3.70705524  3.49478361  1.36057409  4.7644368
#   2.80332948  1.02245647  4.66936117  3.59044246  2.93418248  1.99468958
#   3.48360767  2.62666723  3.26286176  3.3660977   2.35102038  2.61408878
#   3.83023738  2.37678462  3.48761876  2.30471196  3.93856509  3.61867978
#   3.52270398  1.6608072   2.07336469  2.03279275  2.33110404  2.76144009
#   3.57552557  3.91877604  3.11530796  1.49644215  1.29467236  3.33664372
#   4.19410986  4.10803349  0.51021542  1.75410294  3.48501423  2.63673271
#   2.93436501  3.79177075  2.6211257   2.77605617  5.04405317  1.66948246
#   2.52083267  2.38299922  2.34106462  2.90422398  3.54562513  2.52285136
#   4.04179406  3.11009276  3.30526133  3.1399414   3.76604232  4.5288422
#   2.90756618  2.70046134  3.73808573  2.14291063  4.24583411  4.12657931
#   2.02038544  3.3075587   3.20352878  3.85953379  4.67355551  3.41733297
#   3.24778554  2.67448627  3.89311513  3.04221061  1.79126179  2.58584244
#   2.99907062  4.87071972  1.79563572  2.91823366  2.86414071  1.38892922
#   4.16136776  2.27969037  2.15524373  3.51569961  3.33107231  3.05687275
#   2.95712501  2.51715317  1.91721843  3.33200337  4.30164322  3.5664837
#   3.22271843  3.19005142  1.0881835   2.64319249  4.28910367  3.1883734
#   2.66956821  2.75209065  3.59928765  2.8865782   5.07187674  2.53311545
#   2.48310526  2.94193649  2.21285182  2.10802873  2.66448023  3.92862385
#   2.50379277  2.58078185  4.52054344  3.41848849  3.07250995  4.38289629
#   3.82181378  4.29276586  2.55442788  3.95933011  1.84117758  3.08708098
#   5.14696946  2.46101884  4.09259342  2.46554522  3.01574025  3.94504694
#   1.41278243  4.74246449  1.78511419  2.7454803   3.56352539  2.6339572
#   3.13936652  2.67865435  2.56012348  2.23055106  4.56935191  4.64784455
#   2.29466734  3.80043136  2.52297971  1.69222238  4.61961476  4.43858365
#   2.98032154  3.45427317  5.87391265  4.58872218  3.96762522  1.55801265
#   2.22091174  3.98037055  3.20582285  3.24551516  3.19610591  2.76590776
#   2.09296667  2.03548608  3.93568103  2.48827323  3.87396239  4.40980008
#   1.17766841  3.10804793  3.03114901  2.7820678   2.56644533  4.20139169
#   3.29786503  3.51792104  2.89099477  4.71921127  2.01738818  3.33167502
#   4.24075735  3.40352574  3.25502829  1.50823933]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-bbbda9c2d74e> in <module>()
#       5 x2_label2 = np.random.normal(6, 1, 1000)
#       6 x1s = np.append(x1_label1, x1_label2)
# ----> 7 print x1s.shape()
#       8 x2s = np.append(x2_label1, x2_label2)
#       9 ys = np.asarray([0.] * len(x1_label1) + [1.] * len(x1_label2))
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# Define placeholders, variables, model, and the training op:

# %%
X1 = tf.placeholder(tf.float32, shape=(None,), name="x1")
X2 = tf.placeholder(tf.float32, shape=(None,), name="x2")
Y = tf.placeholder(tf.float32, shape=(None,), name="y")
w = tf.Variable([0., 0., 0.], name="w", trainable=True)

y_model = tf.sigmoid(-(w[2] * X2 + w[1] * X1 + w[0]))
cost = tf.reduce_mean(-tf.log(y_model * Y + (1 - y_model) * (1 - Y)))
train_op = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# Train the model on the data in a session:

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    prev_err = 0
    for epoch in range(training_epochs):
        err, _ = sess.run([cost, train_op], {X1: x1s, X2: x2s, Y: ys})
        if epoch % 100 == 0:
            print(epoch, err)
        if abs(prev_err - err) < 0.0001:
            break
        prev_err = err

    w_val = sess.run(w, {X1: x1s, X2: x2s, Y: ys})
# Out:
# 0 0.693147
# 100 0.375964
# 200 0.276061
# 300 0.218569
# 400 0.181875
# 500 0.156599
# 600 0.13817
# 700 0.124143

# %% [markdown]
# Here's one hacky, but simple, way to figure out the decision boundary of the classifier:

# %%
x1_boundary, x2_boundary = [], []
with tf.Session() as sess:
    for x1_test in np.linspace(0, 10, 20):
        for x2_test in np.linspace(0, 10, 20):
            z = sess.run(tf.sigmoid(-x2_test*w_val[2] - x1_test*w_val[1] - w_val[0]))
            if abs(z - 0.5) < 0.05:
                x1_boundary.append(x1_test)
                x2_boundary.append(x2_test)

# %% [markdown]
# Ok, enough code. Let's see some a pretty plot:

# %%
plt.scatter(x1_boundary, x2_boundary, c='b', marker='o', s=20)
plt.scatter(x1_label1, x2_label1, c='r', marker='x', s=20)
plt.scatter(x1_label2, x2_label2, c='g', marker='1', s=20)

plt.show()
