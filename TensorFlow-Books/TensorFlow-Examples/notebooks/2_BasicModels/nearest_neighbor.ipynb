# %%
# A nearest neighbor learning algorithm example using TensorFlow library.
# This example is using the MNIST database of handwritten digits
# (http://yann.lecun.com/exdb/mnist/)

# Author: Aymeric Damien
# Project: https://github.com/aymericdamien/TensorFlow-Examples/

# %%
import numpy as np
import tensorflow as tf

# Import MINST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# In this example, we limit mnist data
Xtr, Ytr = mnist.train.next_batch(5000) #5000 for training (nn candidates)
Xte, Yte = mnist.test.next_batch(200) #200 for testing

# tf Graph Input
xtr = tf.placeholder("float", [None, 784])
xte = tf.placeholder("float", [784])

# Nearest Neighbor calculation using L1 Distance
# Calculate L1 Distance
distance = tf.reduce_sum(tf.abs(tf.add(xtr, tf.negative(xte))), reduction_indices=1)
# Prediction: Get min distance index (Nearest neighbor)
pred = tf.arg_min(distance, 0)

accuracy = 0.

# Initializing the variables
v1 = tf.Variable(1.0, name="v1")
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    # loop over test data
    for i in range(len(Xte)):
        # Get nearest neighbor
        nn_index = sess.run(pred, feed_dict={xtr: Xtr, xte: Xte[i, :]})
        # Get nearest neighbor class label and compare it to its true label
        print "Test", i, "Prediction:", np.argmax(Ytr[nn_index]), \
            "True Class:", np.argmax(Yte[i])
        # Calculate accuracy
        if np.argmax(Ytr[nn_index]) == np.argmax(Yte[i]):
            accuracy += 1./len(Xte)
    print "Done!"
    print "Accuracy:", accuracy
    saver.save(sess, 'model-2')
# Out:
# Test 0 Prediction: 2 True Class: 2
# Test 1 Prediction: 8 True Class: 8
# Test 2 Prediction: 3 True Class: 3
# Test 3 Prediction: 7 True Class: 8
# Test 4 Prediction: 2 True Class: 2
# Test 5 Prediction: 4 True Class: 4
# Test 6 Prediction: 8 True Class: 5
# Test 7 Prediction: 0 True Class: 0
# Test 8 Prediction: 3 True Class: 3
# Test 9 Prediction: 1 True Class: 1
# Test 10 Prediction: 7 True Class: 7
# Test 11 Prediction: 7 True Class: 7
# Test 12 Prediction: 3 True Class: 5
# Test 13 Prediction: 7 True Class: 7
# Test 14 Prediction: 9 True Class: 9
# Test 15 Prediction: 7 True Class: 7
# Test 151 Prediction: 1 True Class: 7
# Test 152 Prediction: 0 True Class: 0
# Test 153 Prediction: 8 True Class: 8
# Test 154 Prediction: 7 True Class: 7
# Test 155 Prediction: 4 True Class: 4
# Test 156 Prediction: 4 True Class: 4
# Test 157 Prediction: 7 True Class: 7
# Test 158 Prediction: 9 True Class: 9
# Test 159 Prediction: 6 True Class: 6
# Test 160 Prediction: 9 True Class: 9
# Test 161 Prediction: 0 True Class: 0
# Test 162 Prediction: 9 True Class: 9
# Test 163 Prediction: 8 True Class: 8
# Test 164 Prediction: 0 True Class: 0
# Test 165 Prediction: 9 True Class: 4
# Test 166 Prediction: 6 True Class: 6
# Test 167 Prediction: 0 True Class: 0
# Test 168 Prediction: 6 True Class: 6
# Test 169 Prediction: 3 True Class: 3
# Test 170 Prediction: 5 True Class: 5
# Test 171 Prediction: 9 True Class: 4
# Test 172 Prediction: 8 True Class: 8
# Test 173 Prediction: 3 True Class: 3
# Test 174 Prediction: 3 True Class: 3
# Test 175 Prediction: 9 True Class: 9
# Test 176 Prediction: 3 True Class: 3
# Test 177 Prediction: 3 True Class: 3
# Test 178 Prediction: 8 True Class: 3
# Test 179 Prediction: 7 True Class: 7
# Test 180 Prediction: 8 True Class: 8
# Test 181 Prediction: 0 True Class: 0
# Test 182 Prediction: 3 True Class: 8
# Test 183 Prediction: 7 True Class: 2
# Test 184 Prediction: 1 True Class: 1
# Test 185 Prediction: 7 True Class: 7
# Test 186 Prediction: 0 True Class: 0
# Test 187 Prediction: 6 True Class: 6
# Test 188 Prediction: 5 True Class: 5
# Test 189 Prediction: 4 True Class: 4
# Test 190 Prediction: 3 True Class: 3
# Test 191 Prediction: 3 True Class: 8
# Test 192 Prediction: 0 True Class: 0
# Test 193 Prediction: 9 True Class: 9
# Test 194 Prediction: 6 True Class: 6
# Test 195 Prediction: 3 True Class: 3
# Test 196 Prediction: 8 True Class: 8
# Test 197 Prediction: 0 True Class: 0
# Test 198 Prediction: 9 True Class: 9
# Test 199 Prediction: 9 True Class: 9
# Done!
# Accuracy: 0.87

# %%
! ls -l
# Out:
# 总用量 116
# -rw-rw-r-- 1 haijunz haijunz    71  4月 12 20:51 checkpoint
# -rw-rw-r-- 1 haijunz haijunz 61961  4月 12 20:39 linear_regression.ipynb
# -rw-rw-r-- 1 haijunz haijunz  5086  4月 12 20:23 logistic_regression.ipynb
# drwxr-xr-x 2 haijunz haijunz  4096  4月 12 20:39 MNIST_data
# -rw-rw-r-- 1 haijunz haijunz     8  4月 12 20:51 model-2.data-00000-of-00001
# -rw-rw-r-- 1 haijunz haijunz   136  4月 12 20:51 model-2.index
# -rw-rw-r-- 1 haijunz haijunz  6245  4月 12 20:51 model-2.meta
# -rw-rw-r-- 1 haijunz haijunz 16791  4月 12 20:50 nearest_neighbor.ipynb
